# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Coffee_domestic_consumption.csv")

# %%
df
# Out:
#                              Country      Coffee type    1990/91    1991/92  \
# 0                             Angola  Robusta/Arabica    1200000    1800000
# 1   Bolivia (Plurinational State of)          Arabica    1500000    1620000
# 2                             Brazil  Arabica/Robusta  492000000  510000000
# 3                            Burundi  Arabica/Robusta     120000      96000
# 4                            Ecuador  Arabica/Robusta   21000000   21000000
# 5                          Indonesia  Robusta/Arabica   74520000   76800000
# 6                         Madagascar          Robusta   21000000   18000000
# 7                             Malawi          Arabica     120000     120000
# 8                   Papua New Guinea  Arabica/Robusta     180000     180000
# 9                           Paraguay          Arabica     900000     900000
# 10                              Peru          Arabica   11400000   11400000
# ...

# %%
df.tail()
# Out:
#               Country      Coffee type   1990/91   1991/92   1992/93  \
# 50  Trinidad & Tobago          Robusta    480000    690000    600000
# 51             Uganda  Robusta/Arabica   4200000   4500000   4500000
# 52          Venezuela          Arabica  46943400  48928800  50998200
# 53           Viet Nam  Robusta/Arabica   9000000  13800000  15000000
# 54              Yemen          Arabica         0         0         0
#
#      1993/94   1994/95   1995/96   1996/97   1997/98  ...   2011/12  \
# 50    600000    840000    840000    840000    840000  ...    600000
# 51   4500000   4800000   4800000   4800000   6071400  ...  12600000
# 52  53155800  55404000  57747600  60190800  62736599  ...  99000000
# 53  16020000  16020000  16910700  17850960  18843480  ...  99000000
# 54         0         0         0         0         0  ...   7800000
#
#       2012/13    2013/14    2014/15    2015/16    2016/17    2017/18  \
# ...

# %%
df.head()
# Out:
#                             Country      Coffee type    1990/91    1991/92  \
# 0                            Angola  Robusta/Arabica    1200000    1800000
# 1  Bolivia (Plurinational State of)          Arabica    1500000    1620000
# 2                            Brazil  Arabica/Robusta  492000000  510000000
# 3                           Burundi  Arabica/Robusta     120000      96000
# 4                           Ecuador  Arabica/Robusta   21000000   21000000
#
#      1992/93    1993/94    1994/95    1995/96    1996/97    1997/98  ...  \
# 0    2100000    1200000    1500000     600000    1200000    2400000  ...
# 1    1650000    1710000    1770000    1830000    1890000    1950000  ...
# 2  534000000  546000000  558000000  606000000  660000000  690000000  ...
# 3     102000     114600     120000     120000     120000     120000  ...
# 4   21000000   21000000   21000000   21000000   18000000   18000000  ...
#
# ...

# %%
df.describe()
# Out:
#             1990/91       1991/92       1992/93       1993/94       1994/95  \
# count  5.500000e+01  5.500000e+01  5.500000e+01  5.500000e+01  5.500000e+01
# mean   2.128278e+07  2.206701e+07  2.285613e+07  2.301590e+07  2.330200e+07
# std    6.810062e+07  7.032839e+07  7.363077e+07  7.511769e+07  7.679945e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.800000e+05  1.800000e+05  1.800000e+05  2.400000e+05  2.400000e+05
# 50%    2.040000e+06  3.000000e+06  3.000000e+06  2.400000e+06  3.000000e+06
# 75%    1.299000e+07  1.671300e+07  1.650000e+07  1.731000e+07  1.650000e+07
# max    4.920000e+08  5.100000e+08  5.340000e+08  5.460000e+08  5.580000e+08
#
#             1995/96       1996/97       1997/98       1998/99       1999/00  \
# count  5.500000e+01  5.500000e+01  5.500000e+01  5.500000e+01  5.500000e+01
# mean   2.465735e+07  2.565010e+07  2.647750e+07  2.739992e+07  2.808131e+07
# ...

# %%
df.shape
# Out:
# (55, 33)

# %%
df.isnull()
# Out:
#     Country  Coffee type  1990/91  1991/92  1992/93  1993/94  1994/95  \
# 0     False        False    False    False    False    False    False
# 1     False        False    False    False    False    False    False
# 2     False        False    False    False    False    False    False
# 3     False        False    False    False    False    False    False
# 4     False        False    False    False    False    False    False
# 5     False        False    False    False    False    False    False
# 6     False        False    False    False    False    False    False
# 7     False        False    False    False    False    False    False
# 8     False        False    False    False    False    False    False
# 9     False        False    False    False    False    False    False
# 10    False        False    False    False    False    False    False
# 11    False        False    False    False    False    False    False
# ...

# %%
import missingno

# %%
missingno.bar(df, color ='r')
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Country                     55 non-null     object
#  1   Coffee type                 55 non-null     object
#  2   1990/91                     55 non-null     int64
#  3   1991/92                     55 non-null     int64
#  4   1992/93                     55 non-null     int64
#  5   1993/94                     55 non-null     int64
#  6   1994/95                     55 non-null     int64
#  7   1995/96                     55 non-null     int64
#  8   1996/97                     55 non-null     int64
#  9   1997/98                     55 non-null     int64
#  10  1998/99                     55 non-null     int64
#  11  1999/00                     55 non-null     int64
#  12  2000/01                     55 non-null     int64
# ...

# %%
sns.displot(df["Coffee type"])

# %%
sns.set_style("whitegrid"),sns.displot(df["Coffee type"])
# Out:
# (None, <seaborn.axisgrid.FacetGrid at 0x20f41650b20>)

# %%
uniqueName = []
for i in df.columns:
    x = df[i].value_counts().count()
    uniqueName.append(x)

pd.DataFrame(uniqueName,index=df.columns,columns=["TotaluniqueName"])
# Out:
#                             TotaluniqueName
# Country                                  55
# Coffee type                               4
# 1990/91                                  42
# 1991/92                                  44
# 1992/93                                  44
# 1993/94                                  41
# 1994/95                                  39
# 1995/96                                  41
# 1996/97                                  39
# 1997/98                                  38
# 1998/99                                  40
# 1999/00                                  40
# 2000/01                                  41
# 2001/02                                  40
# 2002/03                                  45
# 2003/04                                  46
# 2004/05                                  47
# 2005/06                                  47
# 2006/07                                  46
# 2007/08                                  46
# ...
